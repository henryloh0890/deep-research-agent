# %%
from dotenv import load_dotenv
import os

load_dotenv("../.env")

print("Anthropic key loaded:", bool(os.getenv("ANTHROPIC_API_KEY")))
print("Groq key loaded:", bool(os.getenv("GROQ_API_KEY")))
# Out:
# Anthropic key loaded: True
# Groq key loaded: True

# %%
from langchain_anthropic import ChatAnthropic
from langchain_openai import ChatOpenAI

# Primary LLM - Claude (best for writing & synthesis)
claude = ChatAnthropic(model="claude-sonnet-4-5", temperature=0)

# Fast & free LLM - Groq/Llama
groq_llm = ChatOpenAI(
    model="llama-3.3-70b-versatile",
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY"),
    temperature=0
)

# Sanity check both
print("Claude:", claude.invoke("Say hello in one sentence.").content)
print("Groq:", groq_llm.invoke("Say hello in one sentence.").content)
# Out:
# Claude: Hello, it's nice to meet you!
# Groq: Hello, it's nice to meet you and I'm here to help with any questions or topics you'd like to discuss.

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults(num_results=5)

# Test the search
results = search.invoke("AI agent frameworks 2025")
print(results)
# Out:
# Impersonate 'safari_15.3' does not exist, using 'random'
# snippet: insightsoftware.com has been visited by 100K+ users in the past month Connect AI agents to governed enterprise data. Autonomous, auditable, and verifiable. Agentic querying with governance. Reduce manual work while maintaining full auditability. Easy to install and use · Operational Report Tool · Financial Reporting Tool · 27.000+ Customers, title: AI Agent Connectivity Platform - Self-Verifying AI Agents, link: https://www.bing.com/aclick?ld=e806FJexHayO9zpiMV-KL7zjVUCUzRhqQWz5NMydPp9yVxlWS4oN7uTkkryJhpikP2D9hj3bu8Tb4hbDdx-PjWe9WURRocqVWMzlcl9u-fIE1CF3iQURGZFYbT6NilNVJGduQktiwY_HnQroNCHxSpNWYWIKKmyBZ08wrxL-ft_qV7t-zG-wKS7EAQ9DXGptHgiRTSJIzShR6egdVPw7cB9WDaitY&u=...&rlid=fef39b8de37312897a2df22cf66a0730, snippet: uipath.com has been visited by 10K+ users in the past month 78% of execs say they must reinvent models to capture agentic automation’s full value. See how top organizations turn vision into action and action into measurable ROI., title: 2026 AI & Agentic Trends - The Future of AI in 2026, link: https://www.bing.com/aclick?ld=e8pR-V0ylACUPfY91ZxMV7LzVUCUw-K3U2VCSJDLinvdinEg9glVr_9IiDn8brjkYSItNaGAKSuTnu43J6A8r9r2sIeUnubjjUn41W1IcRwrFA9-eDsup28XUNZYDmkYjqGHkCpW1GNetTeWXNtJBtRQPFsFAuybfmDEj04qLWmnuzXvJpjFCYZupk2nbVnUa4rf-tgVL_EkjUJuWbczbTmdyvJ10&u=...&rlid=4748df258d331cb6f193b684982a863e, snippet: Jan 15, 2025 · Comprehensive guide to the best AI agent frameworks in 2025. Compare 25+ frameworks including Agentbase, AutoGen, LangChain, CrewAI , and more for building production-ready AI agents., title: Top 25 AI Agent Frameworks in 2025: Complete Developer Guide, link: https://www.agentbase.sh/blog/ai-agent-guides/top-ai-agent-frameworks-2025, snippet: Jul 2, 2025 · This guide explores the top 10 LLM agent frameworks in 2025 , focusing heavily on Python AI frameworks since Python continues to dominate the AI development ecosystem., title: Top 10 AI Agent Frameworks of 2025 - Medium, link: https://medium.com/@lambert.watts.809/top-10-best-ai-frameworks-for-building-ai-agents-in-2025-137fafb37a46, snippet: Explore the top 7 AI agent frameworks in 2025 (Updated Sept 2025). Compare LangChain, AutoGen, Google ADK, OpenAI SDK & more — features, use cases, and how to pick., title: Top 7 AI Agent Frameworks in 2025 — Ultimate Guide, link: https://www.ampcome.com/post/top-7-ai-agent-frameworks-in-2025

# %%
from langgraph.prebuilt import create_react_agent
from langchain_core.messages import HumanMessage

# Create agent with search tool attached
agent = create_react_agent(claude, tools=[search])

# Test run the agent
result = agent.invoke({
    "messages": [HumanMessage(content="Research the latest trends in AI agents in 2025. Give me 5 key insights.")]
})

# Print the final response
print(result["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.agents import create_react_agent
#       2 from langchain_core.messages import HumanMessage
#       4 # Create agent with search tool attached
#
# ImportError: cannot import name 'create_react_agent' from 'langchain.agents' (C:\Users\Henry\anaconda3\envs\research-agent\Lib\site-packages\langchain\agents\__init__.py)
